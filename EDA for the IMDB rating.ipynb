# %% [markdown]
# # Project Description:
#
# We have created a dataset for the IMDB movie rating in csv format and later we have to do the EDA for the dataset and after
# successfully completing the EDA we have to make the model to predict the 'Gross' and 'Vote' for the movies.
# So there is two csv file for the dataset, we are going to cancade the dataset for the EDA.

# %%
#importing the requried library

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file and uploading the dataset for the EDA

# %%
df=pd.read_csv('file1.csv')
df
# Out:
#       Unnamed: 0  SrNO                                        movie_names  \
# 0              0     1                Spider-Man: Across the Spider-Verse
# 1              1     2                                    The Dark Knight
# 2              2     3      The Lord of the Rings: The Return of the King
# 3              3     4                                          Inception
# 4              4     5  The Lord of the Rings: The Fellowship of the Ring
# ...          ...   ...                                                ...
# 1695        1695  1696                                         Species II
# 1696        1696  1697                                       Home Alone 3
# 1697        1697  1698                                               Taxi
# 1698        1698  1699                                            Skyline
# 1699        1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list  metascore_list  rating_list
# ...

# %%
#now uploding the second file or table for the EDA:

# %%
df1=pd.read_csv('file2.csv')
df1
# Out:
#       Unnamed: 0                                        movie_names  \
# 0              0                Spider-Man: Across the Spider-Verse
# 1              1                                    The Dark Knight
# 2              2      The Lord of the Rings: The Return of the King
# 3              3                                          Inception
# 4              4  The Lord of the Rings: The Fellowship of the Ring
# ...          ...                                                ...
# 1695        1695                                         Species II
# 1696        1696                                       Home Alone 3
# 1697        1697                                               Taxi
# 1698        1698                                            Skyline
# 1699        1699                            xXx: State of the Union
#
#               star_name1            star_name2       star_name3  \
# 0            Kemp Powers    Justin K. Thompson    Shameik Moore
# ...

# %% [markdown]
# Now we have our dataset for which i need to do the EDA.First of all we have to cancatinate these two datasets to perform the EDA.

# %%
#cancatinating these two datsets while deleting the duplicates columns if any :

# %%
df = pd.concat([df.T.drop_duplicates().T, df1], axis=1)

# %%
df
# Out:
#       Unnamed: 0  SrNO                                        movie_names  \
# 0              0     1                Spider-Man: Across the Spider-Verse
# 1              1     2                                    The Dark Knight
# 2              2     3      The Lord of the Rings: The Return of the King
# 3              3     4                                          Inception
# 4              4     5  The Lord of the Rings: The Fellowship of the Ring
# ...          ...   ...                                                ...
# 1695        1695  1696                                         Species II
# 1696        1696  1697                                       Home Alone 3
# 1697        1697  1698                                               Taxi
# 1698        1698  1699                                            Skyline
# 1699        1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list metascore_list rating_list  \
# ...

# %% [markdown]
# now we have a single dataset on which we need to perform the EDA so let us start the EDA for the above dataformat:

# %%
# Assuming you have a DataFrame named df with a column named "gross"

# Define a function to convert the monetary value to a numerical format
def convert_to_numeric(value):
    # Remove the dollar sign and "M" suffix
    value = value.replace('$', '').replace('M', '')
    # Convert to float and multiply by 1 million
    return float(value) * 1_000_000

# Apply the conversion function to the "gross" column
df['Gross'] = df['Gross'].apply(convert_to_numeric)

# Print the updated DataFrame
print(df)
# Out:
#       Unnamed: 0  SrNO                                        movie_names  \
# 0              0     1                Spider-Man: Across the Spider-Verse
# 1              1     2                                    The Dark Knight
# 2              2     3      The Lord of the Rings: The Return of the King
# 3              3     4                                          Inception
# 4              4     5  The Lord of the Rings: The Fellowship of the Ring
# ...          ...   ...                                                ...
# 1695        1695  1696                                         Species II
# 1696        1696  1697                                       Home Alone 3
# 1697        1697  1698                                               Taxi
# 1698        1698  1699                                            Skyline
# 1699        1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list metascore_list rating_list  \
# ...

# %% [markdown]
# # EDA:(Exploratry Data Analysis)

# %%
#information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1700 non-null   object
#  1   SrNO            1700 non-null   object
#  2   movie_names     1700 non-null   object
#  3   director_names  1590 non-null   object
#  4   duration_list   1700 non-null   object
#  5   year_list       1700 non-null   object
#  6   metascore_list  533 non-null    object
#  7   rating_list     1700 non-null   object
#  8   Unnamed: 0      1700 non-null   int64
#  9   movie_names     1700 non-null   object
#  10  star_name1      1700 non-null   object
#  11  star_name2      1699 non-null   object
#  12  star_name3      1699 non-null   object
#  13  star_name4      1698 non-null   object
#  14  votes_list      1700 non-null   object
#  15  Gross           1700 non-null   float64
#  16  certification   1694 non-null   object
# ...

# %% [markdown]
# From the above information wer can get the Datatype of the columns and whether our columns have null values or not...

# %% [markdown]
# We have observed that the datatype of the votes_list is object but need to convert its datattype from object to intiger so here is the code.

# %%
# Assuming you have a DataFrame named df and a column named 'vote'

df['votes_list'] = df['votes_list'].str.replace(',', '')

# %%
df['votes_list'] = pd.to_numeric(df['votes_list'])

# %%
df
# Out:
#       Unnamed: 0  SrNO                                        movie_names  \
# 0              0     1                Spider-Man: Across the Spider-Verse
# 1              1     2                                    The Dark Knight
# 2              2     3      The Lord of the Rings: The Return of the King
# 3              3     4                                          Inception
# 4              4     5  The Lord of the Rings: The Fellowship of the Ring
# ...          ...   ...                                                ...
# 1695        1695  1696                                         Species II
# 1696        1696  1697                                       Home Alone 3
# 1697        1697  1698                                               Taxi
# 1698        1698  1699                                            Skyline
# 1699        1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list metascore_list rating_list  \
# ...

# %%
#let us change the Datatype of the Gross colum

# %%
df['Gross']=df['Gross'].astype(int)

# %%
df['Gross'].dtype
# Out:
# dtype('int32')

# %%
df
# Out:
#       Unnamed: 0  SrNO                                        movie_names  \
# 0              0     1                Spider-Man: Across the Spider-Verse
# 1              1     2                                    The Dark Knight
# 2              2     3      The Lord of the Rings: The Return of the King
# 3              3     4                                          Inception
# 4              4     5  The Lord of the Rings: The Fellowship of the Ring
# ...          ...   ...                                                ...
# 1695        1695  1696                                         Species II
# 1696        1696  1697                                       Home Alone 3
# 1697        1697  1698                                               Taxi
# 1698        1698  1699                                            Skyline
# 1699        1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list metascore_list rating_list  \
# ...

# %%
#the shape of the datset
df.shape
# Out:
# (1700, 20)

# %% [markdown]
# From the above code we get to know that in our dataset there is 1700 rows and 20 columns

# %%
# the columns name
df.columns
# Out:
# Index(['Unnamed: 0', 'SrNO', 'movie_names', 'director_names', 'duration_list',
#        'year_list', 'metascore_list', 'rating_list', 'Unnamed: 0',
#        'movie_names', 'star_name1', 'star_name2', 'star_name3', 'star_name4',
#        'votes_list', 'Gross', 'certification', 'Genre', 'Genre2', 'Genre3'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 20

# %%
#finding the duplicates in the dataset

# %%
duplicate_columns = df.columns[df.columns.duplicated()]

# %%
#dropping the Duplicates columns from the dataset:
df = df.loc[:, ~df.columns.duplicated()]

# %%
df
# Out:
#      Unnamed: 0  SrNO                                        movie_names  \
# 0             0     1                Spider-Man: Across the Spider-Verse
# 1             1     2                                    The Dark Knight
# 2             2     3      The Lord of the Rings: The Return of the King
# 3             3     4                                          Inception
# 4             4     5  The Lord of the Rings: The Fellowship of the Ring
# ...         ...   ...                                                ...
# 1695       1695  1696                                         Species II
# 1696       1696  1697                                       Home Alone 3
# 1697       1697  1698                                               Taxi
# 1698       1698  1699                                            Skyline
# 1699       1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list metascore_list rating_list  \
# ...

# %%
#again finding the data shape for the dataset
df.shape
# Out:
# (1700, 18)

# %% [markdown]
# Now we have reduced our columns from 20 to 18 by dropping the duplicates.Those duplicates were 'movie_names' and 'unnamed' columns
#
# now in our datset these two columns are not present:

# %%
#finding the null values from the dataset
df.isnull().sum()
# Out:
# Unnamed: 0           0
# SrNO                 0
# movie_names          0
# director_names     110
# duration_list        0
# year_list            0
# metascore_list    1167
# rating_list          0
# star_name1           0
# star_name2           1
# star_name3           1
# star_name4           2
# votes_list           0
# Gross                0
# certification        6
# Genre                0
# Genre2               0
# Genre3             306
# dtype: int64

# %% [markdown]
# Observation:
#
# From the above code we can conclude as:
#     In the columns named 'director_names','metascore_list','Genre3' having the lots of null values while in some other coloumns
#     named 'star_name2','star_nmae3','star_name4','certification' ,having only one or less null values.
#
#     In the columns in which null values are greater than 50% of the dataset, we will drop that column otherwise we are going to
#
#     treat the null values by replacing the mean and mode values as per requirments

# %% [markdown]
# Before going to treatment of the null values i am going to check the unique values of the columns:

# %%
#finding the unique values in the columns
df.nunique().to_frame("Unique Values")
# Out:
#                 Unique Values
# Unnamed: 0               1700
# SrNO                     1700
# movie_names              1670
# director_names            831
# duration_list             118
# year_list                 112
# metascore_list             35
# rating_list                45
# star_name1                739
# star_name2               1115
# star_name3               1287
# star_name4               1410
# votes_list               1695
# Gross                    1324
# certification              16
# Genre                       2
# Genre2                      8
# Genre3                      9

# %% [markdown]
# The columns having less unique values can be dropped as per our requirments so we will drop the columns if we do not required for the EDA:

# %%
#dropping the unnecessary columns from the dataset for the better accurecy of EDA:

# %%
df=df.drop(['Unnamed: 0','metascore_list','Genre','certification'],axis=1)

# %%
df
# Out:
#       SrNO                                        movie_names  \
# 0        1                Spider-Man: Across the Spider-Verse
# 1        2                                    The Dark Knight
# 2        3      The Lord of the Rings: The Return of the King
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1695  1696                                         Species II
# 1696  1697                                       Home Alone 3
# 1697  1698                                               Taxi
# 1698  1699                                            Skyline
# 1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list rating_list  \
# 0     Christopher Nolan       140 min      (2023)         9.0
# 1         Peter Jackson       152 min      (2008)         9.0
# ...

# %% [markdown]
# Observation:
# We have dropped the 'unnamed:0','Genre','certification' and 'metascore_list' which have large ammount of null values and
#
# not having too much requirement for the EDA. After dropping these columns we have a new dataset.

# %%
#Treating the null values

# %% [markdown]
# I am going to treat the null values by using the mean imputation method for the numerical values and mode imputation method
# for the categorical columns.

# %%
#once again lets find the null values for the ref.

# %%
df.isnull().sum()
# Out:
# SrNO                0
# movie_names         0
# director_names    110
# duration_list       0
# year_list           0
# rating_list         0
# star_name1          0
# star_name2          1
# star_name3          1
# star_name4          2
# votes_list          0
# Gross               0
# Genre2              0
# Genre3            306
# dtype: int64

# %%
# Specify the columns for which i want to replace null values with mode
columns_to_replace = ['director_names', 'star_name2', 'star_name3','star_name4','Genre3']

# Create a copy of the DataFrame
df_filled = df.copy()

# Iterate over the specified columns
for column in columns_to_replace:
    mode_value = df_filled[column].mode()[0]  # Get the mode value for the column
    df_filled[column].fillna(mode_value, inplace=True)  # Replace null values with mode value

# Drop rows with any remaining null values
df_filled.dropna(inplace=True)

# Print the DataFrame with null values replaced and rows dropped
print(df_filled)
# Out:
#       SrNO                                        movie_names  \
# 0        1                Spider-Man: Across the Spider-Verse
# 1        2                                    The Dark Knight
# 2        3      The Lord of the Rings: The Return of the King
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1695  1696                                         Species II
# 1696  1697                                       Home Alone 3
# 1697  1698                                               Taxi
# 1698  1699                                            Skyline
# 1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list rating_list  \
# 0     Christopher Nolan       140 min      (2023)         9.0
# 1         Peter Jackson       152 min      (2008)         9.0
# ...

# %% [markdown]
#  I have treated the null values with mode imputation method because all the columns were categorical values...

# %%
#Lets cross varify for the null values in the datset

# %%
df_filled.isnull().sum()
# Out:
# SrNO              0
# movie_names       0
# director_names    0
# duration_list     0
# year_list         0
# rating_list       0
# star_name1        0
# star_name2        0
# star_name3        0
# star_name4        0
# votes_list        0
# Gross             0
# Genre2            0
# Genre3            0
# dtype: int64

# %% [markdown]
# Observation:
#
# now we can see that there is not any null values in the dataset do we can proceed further for the EDA:

# %%
#checking for the zero values

# %%
zero_values = (df_filled == 0).sum()

# %%
zero_values
# Out:
# SrNO                0
# movie_names         0
# director_names      0
# duration_list       0
# year_list           0
# rating_list         0
# star_name1          0
# star_name2          0
# star_name3          0
# star_name4          0
# votes_list          0
# Gross             271
# Genre2              0
# Genre3              0
# dtype: int64

# %% [markdown]
# #Treat the zero values
#
# #Observation:
#
# If the column with the zero values is the target variable we are trying to predict, it is generally not advisable to
# remove or impute those zeros. Since the target variable represents the outcome or response we are trying to model or
# predict, altering or removing the zero values could significantly affect the integrity and accuracy of your analysis.

# %%
df_filled
# Out:
#       SrNO                                        movie_names  \
# 0        1                Spider-Man: Across the Spider-Verse
# 1        2                                    The Dark Knight
# 2        3      The Lord of the Rings: The Return of the King
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1695  1696                                         Species II
# 1696  1697                                       Home Alone 3
# 1697  1698                                               Taxi
# 1698  1699                                            Skyline
# 1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list rating_list  \
# 0     Christopher Nolan       140 min      (2023)         9.0
# 1         Peter Jackson       152 min      (2008)         9.0
# ...

# %%
df_filled.head()
# Out:
#   SrNO                                        movie_names     director_names  \
# 0    1                Spider-Man: Across the Spider-Verse  Christopher Nolan
# 1    2                                    The Dark Knight      Peter Jackson
# 2    3      The Lord of the Rings: The Return of the King  Christopher Nolan
# 3    4                                          Inception      Peter Jackson
# 4    5  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
#
#   duration_list year_list rating_list         star_name1  \
# 0       140 min    (2023)         9.0        Kemp Powers
# 1       152 min    (2008)         9.0     Christian Bale
# 2       201 min    (2003)         9.0        Elijah Wood
# 3       148 min    (2010)         8.8  Leonardo DiCaprio
# 4       178 min    (2001)         8.8        Elijah Wood
#
#              star_name2     star_name3        star_name4  votes_list  \
# 0    Justin K. Thompson  Shameik Moore  Hailee Steinfeld       97467
# ...

# %% [markdown]
# # Stastical Analysis of the Dataset:

# %%
df_filled.describe(include='all')
# Out:
#           SrNO       movie_names director_names duration_list year_list  \
# count   1700.0              1700           1700          1700      1700
# unique  1700.0              1670            831           118       112
# top        1.0  Charlie's Angels    Michael Bay       107 min    (2016)
# freq       1.0                 2            125            45        71
# mean       NaN               NaN            NaN           NaN       NaN
# std        NaN               NaN            NaN           NaN       NaN
# min        NaN               NaN            NaN           NaN       NaN
# 25%        NaN               NaN            NaN           NaN       NaN
# 50%        NaN               NaN            NaN           NaN       NaN
# 75%        NaN               NaN            NaN           NaN       NaN
# max        NaN               NaN            NaN           NaN       NaN
#
#         rating_list          star_name1         star_name2         star_name3  \
# ...

# %%
df_filled.describe()#for numerical column
# Out:
#          votes_list         Gross
# count  1.700000e+03  1.700000e+03
# mean   1.846179e+05  6.601011e+07
# std    2.391372e+05  9.961610e+07
# min    2.505900e+04  0.000000e+00
# 25%    4.849075e+04  3.907500e+06
# 50%    9.992550e+04  3.311000e+07
# 75%    2.175070e+05  8.011750e+07
# max    2.722951e+06  9.366600e+08

# %%
df=df_filled.copy()

# %%
df
# Out:
#       SrNO                                        movie_names  \
# 0        1                Spider-Man: Across the Spider-Verse
# 1        2                                    The Dark Knight
# 2        3      The Lord of the Rings: The Return of the King
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1695  1696                                         Species II
# 1696  1697                                       Home Alone 3
# 1697  1698                                               Taxi
# 1698  1699                                            Skyline
# 1699  1700                            xXx: State of the Union
#
#          director_names duration_list   year_list rating_list  \
# 0     Christopher Nolan       140 min      (2023)         9.0
# 1         Peter Jackson       152 min      (2008)         9.0
# ...

# %% [markdown]
# # Categoraised the dataset by its datatype:

# %%
numerical=df.select_dtypes(include=["int64","int32"]).columns.tolist()
category=df.select_dtypes(include=["object"]).columns.tolist()

# %%
numerical
# Out:
# ['votes_list', 'Gross']

# %%
category
# Out:
# ['SrNO',
#  'movie_names',
#  'director_names',
#  'duration_list',
#  'year_list',
#  'rating_list',
#  'star_name1',
#  'star_name2',
#  'star_name3',
#  'star_name4',
#  'Genre2',
#  'Genre3']

# %% [markdown]
# # Univariate Analysis:

# %% [markdown]
# # Boxplot:(Outlier Detection)

# %%
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,15),color = 'green')
plt.tight_layout()

# %% [markdown]
# Indivisually:

# %%
df['Gross'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#boxplot to find the outliers in votes_list
df['votes_list'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#outliers detection for the rating_list
df['rating_list'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
# From the above observation we can observe that there is outliers preent in the dataset specially in our Gross column
#
# so we are going to use the Ztransform method to treat the outliers..

# %% [markdown]
# Observation:
#
# From the above observation we can observe that there is outliers preent in the dataset specially in our Gross column
#
# so we are going to use the Ztransform method to treat the outliers..

# %% [markdown]
# # Histogram plot for Univariate Analysis

# %%
df.plot.hist(column=['Gross'],figsize=(10,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(column=['votes_list'],figsize=(10,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(column=['rating_list'],figsize=(10,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # visualaization for the skewness :

# %%
#skewness for the 'Gross'
sns.distplot(a = df['Gross'], kde=True,color='pink')
    
plt.show()

# %%
#skewness for the votes_list
sns.distplot(a = df['votes_list'], kde=True,color='red')
    
plt.show()

# %%
#skewness for the rating_list
sns.distplot(a = df['rating_list'], kde=True,color='black')
    
plt.show()

# %% [markdown]
# # skewness:

# %%
x=df.skew()

# %%
x
# Out:
# SrNO           0.000000
# rating_list    0.125155
# votes_list     3.765268
# Gross          3.369496
# dtype: float64

# %% [markdown]
# Observation:
#
# From above observation we can say that there is skewed data present in our columns named 'votes_list' and 'Gross' because the value of the skewed data is 3.7652 and 3.5463 respectively and the allowed value for the skewness should be in range between -0.5 to +0.5.
#
# Lets see skewness in the dataset by visualaization:

# %% [markdown]
# Treatment of the skewness by using power Transformation method:

# %%
from sklearn.preprocessing import power_transform

# %%
#taking the numerical for log Transformation
for col in numerical:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# SrNO           0.000000
# rating_list    0.125155
# votes_list     0.468778
# Gross         -1.612751
# dtype: float64

# %% [markdown]
# Observation:-
# We have Treated the skewed data from dataset by using Log transformation method, as a result we got the skewfree data.

# %%
#skewness for the 'Gross'
sns.distplot(a = df['Gross'], kde=True,color='pink')
    
plt.show()

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# # Bivariate analysis:

# %% [markdown]
# Bivariate analysis to find the relation between two columns:

# %% [markdown]
# # Votes_list Vs movies_names

# %%
top_voted = df.sort_values(['votes_list'], ascending = False)

# %% [markdown]
# Top Voted Movies:

# %%
fig,axs=plt.subplots(figsize=(15,10))
g=sns.barplot(x=top_voted['movie_names'][:7],y=top_voted['votes_list'][:7], palette = 'hls')
g.set_title("Top Voted Movies", weight = "bold")
plt.show()

# %% [markdown]
# # Top voted movie rating:
# rating_list Vs movie_Name

# %%
fig,axs=plt.subplots(figsize=(15,10))
g=sns.barplot(x=top_voted['movie_names'][:7],y=top_voted['rating_list'][:7], palette = 'husl')
g.set_title("IMDB Rating of top voted movies", weight = "bold")
plt.show()

# %% [markdown]
# # Gross Vs Movie_name

# %% [markdown]
# Gross of top rated movie:

# %%
fig,axs=plt.subplots(figsize=(15,10))
g=sns.barplot(x=top_voted['movie_names'][:7],y=top_voted['Gross'][:7], palette = 'husl')
g.set_title("Gross by top rated movies", weight = "bold")
plt.show()

# %% [markdown]
# Top movies by Gross:

# %%
highest_earning = df.sort_values(['Gross'], ascending = False)
fig,axs=plt.subplots(figsize=(23,5))
g=sns.barplot(x=highest_earning['movie_names'][:7],y=highest_earning['Gross'][:7], palette = 'husl')
g.set_title("Movies with highest Gross", weight = "bold")
plt.show()

# %% [markdown]
# Maximum movie release in:

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['year_list'].value_counts()[:10].index,y=df['year_list'].value_counts()[:10])
g.set_title("Maximum Series released in-", weight = "bold")
g.set_xlabel("Years")
plt.show()

# %%
# Moastly Occured director(line plot):

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.lineplot(x=df['director_names'].value_counts()[:10].index,y=df['year_list'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("Directors", weight = "bold")
plt.show()

# %%
# Moastly Occured director(Bar plot):

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['director_names'].value_counts()[:10].index,y=df['director_names'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("Directors", weight = "bold")
plt.show()

# %% [markdown]
# Runtime of the movie:

# %%
import re
duration=[]
for x in df["duration_list"]:
    p=re.compile('\d+')
    j=p.findall(x)
    if len(j)==2:
        duration.append(int(j[1])-int(j[0])+1)
    else:
        duration.append(int(j[0])+1)
df['duration']=duration

# %%
df['duration'].head()
# Out:
# 0    141
# 1    153
# 2    202
# 3    149
# 4    179
# Name: duration, dtype: int64

# %%
fig,axs=plt.subplots(figsize=(20,5))  #time duration of the movies
g=sns.kdeplot(df['duration'])
g.set_title("Time Duration of movies", weight = "bold")
# Out:
# Text(0.5, 1.0, 'Time Duration of movies')

# %% [markdown]
# Stars with most occurence in movies:

# %%
stars=['star_name1','star_name2','star_name3','star_name4']
fig,axs=plt.subplots(4,1,figsize=(20,7))
ax=0
for x in stars:
    axs[ax].bar(df[x].value_counts()[:10].index,df[x].value_counts()[:10])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# Apperence of stars in most voted movies:

# %%
stars=['star_name1','star_name2','star_name3','star_name4']
fig,axs=plt.subplots(4,1,figsize=(20,7))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=s.sort_values(['votes_list'],ascending=False)[:10]
    axs[ax].bar(d[x],d['votes_list'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# Appreance of stars in the top grossed movie:

# %%
stars=['star_name1','star_name2','star_name3','star_name4']
fig,axs=plt.subplots(4,1,figsize=(20,7))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=s.sort_values(['Gross'],ascending=False)[:10]
    axs[ax].bar(d[x],d['Gross'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# TOP 10 Genre:

# %%
from collections import Counter
genre=[]
for x in df['Genre2']:
    for y in x.split(','):
        genre.append(y.strip().lower())

count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(y,x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()

# %% [markdown]
# # Scatterplot:

# %%
sns.scatterplot(x="votes_list",y="Gross",data=df)
plt.figure(figsize=(10, 10))
plt.scatter(df['votes_list'], df['Gross'], s=50)

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %%
#correlation between nthe numerical columns
df.corr()
# Out:
#             votes_list     Gross
# votes_list    1.000000  0.703118
# Gross         0.703118  1.000000

# %%
#heatmap visuallization
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
# From above Heatmap visualaization we can observe that there is no any multicollinearity between the above two numerical column as 'votes_list' and 'Gross'

# %% [markdown]
# # Treatrment for the Outliers:

# %%
#percentile method to treat the outliers
from numpy import percentile

columns = df.columns
for j in columns:
    if isinstance(df[j][0], str) :
        continue
    else:
        #defining quartiles
        quartiles = percentile(df[j], [25,75])
        # calculate min/max
        lower_fence = quartiles[0] - (1.5*(quartiles[1]-quartiles[0]))
        upper_fence = quartiles[1] + (1.5*(quartiles[1]-quartiles[0]))
        df[j] = df[j].apply(lambda x: upper_fence if x > upper_fence else (lower_fence if x < lower_fence else x))

# %%
#let us check the outliers once again..

# %%
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,15),color = 'green')
plt.tight_layout()

# %% [markdown]
# Great now we can observe that there is not any outliers present in the dataset so we can go ahead..

# %% [markdown]
# # Our data preprocessing part has been done now we are going to do the ML part for the Model prediction.

# %% [markdown]
# We have to convert our category data into numerical column for the model prediction in ML.

# %%
#one hot encoder method to convert the categories column into numerical columns

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
df['movie_names'] = label_encoder.fit_transform(df['movie_names'])
df['director_names'] = label_encoder.fit_transform(df['director_names'])
df['duration_list'] = label_encoder.fit_transform(df['duration_list'])
df['star_name1'] = label_encoder.fit_transform(df['star_name1'])
df['star_name2'] = label_encoder.fit_transform(df['star_name2'])
df['star_name3'] = label_encoder.fit_transform(df['star_name3'])
df['star_name4'] = label_encoder.fit_transform(df['star_name4'])
df['Genre2'] = label_encoder.fit_transform(df['Genre2'])
df['Genre3'] = label_encoder.fit_transform(df['Genre3'])
df['year_list'] = label_encoder.fit_transform(df['year_list'])

# %%
df
# Out:
#       SrNO  movie_names  director_names  duration_list  year_list  \
# 0        1         1114             132             40         73
# 1        2         1265             593             52         58
# 2        3         1376             132             87         53
# 3        4          584             593             48         60
# 4        5         1375             593             77         51
# ...    ...          ...             ...            ...        ...
# 1695  1696         1104             510            111         48
# 1696  1697          551             510              2         47
# 1697  1698         1188             510            115         78
# 1698  1699         1075             510            110         60
# 1699  1700         1668             510              1         55
#
#       rating_list  star_name1  star_name2  star_name3  star_name4  votes_list  \
# 0             9.0         383         561        1105         445   97467.000
# ...

# %% [markdown]
# Observation:
#
# The above observation is showing that all our categorical column is being converted into numerical column so it would be easy for the machine modeling.

# %%
#importing the required libraries for the machine learning model building

# %% [markdown]
# Model observation:
#
# From above datset we are going to build the prediction model,as per question our target column is votes_list and Gross
# which is continuous in nature so we are going to use 'Linear Regression' analysis in the supervised learning.First we
# will go for the Gross column as Target column.

# %%
import sklearn
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Splitting the dataset into 2 variables namely 'X' and 'Y' for feature and label

# %%
X=df.drop('Gross',axis=1)
Y=df['Gross']

# %%
df.dtypes
# Out:
# SrNO                int64
# movie_names         int32
# director_names      int32
# duration_list       int32
# year_list           int32
# rating_list       float64
# star_name1          int32
# star_name2          int32
# star_name3          int32
# star_name4          int32
# votes_list        float64
# Gross             float64
# Genre2              int32
# Genre3              int32
# dtype: object

# %%
Y.value_counts()
# Out:
# 0.0            271
# 194432500.0    137
# 30000.0          8
# 10000.0          7
# 40000.0          5
#               ...
# 135270000.0      1
# 134510000.0      1
# 51690000.0       1
# 56850000.0       1
# 26870000.0       1
# Name: Gross, Length: 1188, dtype: int64

# %%
X
# Out:
#       SrNO  movie_names  director_names  duration_list  year_list  \
# 0        1         1114             132             40         73
# 1        2         1265             593             52         58
# 2        3         1376             132             87         53
# 3        4          584             593             48         60
# 4        5         1375             593             77         51
# ...    ...          ...             ...            ...        ...
# 1695  1696         1104             510            111         48
# 1696  1697          551             510              2         47
# 1697  1698         1188             510            115         78
# 1698  1699         1075             510            110         60
# 1699  1700         1668             510              1         55
#
#       rating_list  star_name1  star_name2  star_name3  star_name4  votes_list  \
# 0             9.0         383         561        1105         445   97467.000
# ...

# %%
Y
# Out:
# 0               0.0
# 1       194432500.0
# 2       194432500.0
# 3       194432500.0
# 4       194432500.0
#            ...
# 1695     19170000.0
# 1696     30880000.0
# 1697     36610000.0
# 1698     21370000.0
# 1699     26870000.0
# Name: Gross, Length: 1700, dtype: float64

# %%
df
# Out:
#       SrNO  movie_names  director_names  duration_list  year_list rating_list  \
# 0        1         1114             132             40         73         9.0
# 1        2         1265             593             52         58         9.0
# 2        3         1376             132             87         53         9.0
# 3        4          584             593             48         60         8.8
# 4        5         1375             593             77         51         8.8
# ...    ...          ...             ...            ...        ...         ...
# 1695  1696         1104             510            111         48         4.5
# 1696  1697          551             510              2         47         4.5
# 1697  1698         1188             510            115         78         4.5
# 1698  1699         1075             510            110         60         4.5
# 1699  1700         1668             510              1         55         4.5
#
# ...

# %%
Y.value_counts()
# Out:
# 0.0            271
# 194432500.0    137
# 30000.0          8
# 10000.0          7
# 40000.0          5
#               ...
# 135270000.0      1
# 134510000.0      1
# 51690000.0       1
# 56850000.0       1
# 26870000.0       1
# Name: Gross, Length: 1188, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=50)

# %%
Y_test=np.array(Y_test,dtype=int)

# %% [markdown]
# # Normalising our X_train and X_test by using standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X.skew()
# Out:
# SrNO              0.000000
# movie_names      -0.000906
# director_names   -0.154501
# duration_list     0.841940
# year_list        -0.314732
# rating_list       0.125155
# star_name1        0.021415
# star_name2        0.004019
# star_name3        0.033987
# star_name4        0.021663
# votes_list        1.171058
# Genre2            0.173531
# Genre3            0.336308
# dtype: float64

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(17,15))
index = 0
ax = ax.flatten()
for col, value in X.items():
    sns.distplot(value, ax=ax[index], hist=False, color="green", kde_kws={"shade": True})
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# Observation:
#
# From above observation we are seeing that approx all the columns having the bell shape curve so all are the normal distributed curve.

# %% [markdown]
# # Finding best random state for building the Regression Models

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.6543117021613933 on Random State 769

# %%
from sklearn.decomposition import PCA


# Create a PCA instance
pca = PCA(n_components=2)  # Specify the number of components to keep

# Fit the data and perform dimensionality reduction
X_pca = pca.fit_transform(X)

# Print the explained variance ratio
print("Explained Variance Ratio:", pca.explained_variance_ratio_)

# Access the principal components
components = pca.components_
print("Principal Components:")
for i, component in enumerate(components):
    print(f"PC{i+1}: {component}")

# Visualize the transformed data
import matplotlib.pyplot as plt

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=Y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
plt.show()
# Out:
# Explained Variance Ratio: [9.99952371e-01 1.18514217e-05]
# Principal Components:
# PC1: [-1.54382018e-03  6.29266297e-05 -9.05564727e-05 -4.67607101e-05
#   7.43310675e-06  2.55884456e-06 -3.12092805e-05 -8.29771844e-06
#  -5.39216051e-05 -1.70753361e-04  9.99998785e-01 -1.88571603e-07
#   6.10419399e-07]
# PC2: [ 2.01728845e-02  9.98600007e-01 -6.44613339e-05 -1.02659745e-03
#  -6.39503318e-04 -3.26096856e-05 -4.53674062e-03 -2.49108407e-02
#  -9.23624172e-04  4.18045987e-02 -2.50040715e-05  5.01880814e-05
#  -3.09164706e-08]

# %% [markdown]
# # Machine learning model for Regression with metrics

# %% [markdown]
# Regression Model Function:

# %%
def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=769)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # RMSE - a lower RMSE score is better than a higher one
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score is:", rmse)
    
    # R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of r2 score minus cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
#Linear Regression Model
model=LinearRegression()
reg(model,X,Y)
# Out:
# RMSE Score is: 35263998.31110765
# R2 Score is: 65.12507656749548
# Cross Validation Score: 54.504224449815354
# R2 Score - Cross Validation Score is 10.62085211768013

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([  2077376.44471926,    888889.20698179,    151868.08333332,
#            66384.81911099,  -7062888.79893041, -10193222.35535145,
#           682482.84911974,   1004825.85524447,   -240385.097671  ,
#           208991.72932465,  51823909.58663739,  -1102663.8608515 ,
#           222424.24797496])

# %%
lm.intercept_
# Out:
# 54867897.048529394

# %%
lm.score(X_train,Y_train)
# Out:
# 0.6882443194920631

# %% [markdown]
# # Predict the Values:

# %%
pred=lm.predict(X_test)

# %%
print("predicted result price:",pred)
print("actual price",Y_test)
# Out:
# predicted result price: [ 1.59250317e+08  2.34520960e+07  1.55854427e+08  1.43679834e+08
#   2.61157074e+07  3.48453542e+07  4.16775163e+07  8.40918659e+07
#   2.15904434e+07  1.63253703e+08  2.71412226e+07  1.48769023e+08
#   6.49102850e+07  4.64676230e+07  6.64322481e+07  3.18708854e+07
#   1.31926779e+08  1.53147742e+08  1.54188392e+07  2.37828524e+07
#   1.30906948e+08  1.52311724e+08  1.12593719e+07 -1.12344166e+07
#   2.74854759e+07  5.76679553e+07  9.69286791e+07  1.58045499e+08
#   1.51803566e+08  4.20434768e+07  1.11743828e+08  6.08394121e+07
#   4.27173847e+07  6.52868650e+07  3.52270563e+07 -1.73261265e+07
#   2.27424583e+06  8.30793971e+07  3.55426845e+07  1.21010202e+08
#   7.28688687e+07  8.86962085e+06  9.35034220e+07  7.46673997e+07
#   9.51444516e+07  4.43624981e+07  1.48791651e+08  4.87404855e+07
#   5.68997740e+07  2.48113955e+07  2.48835287e+07  6.70300041e+06
#   1.01633119e+08  1.62640590e+08  7.51867773e+06  5.39266435e+07
# ...

# %% [markdown]
# Model performence

# %%
from sklearn.metrics import r2_score
print(r2_score(Y_test,pred))
# Out:
# 0.6039400101879877

# %%
# RandomForestRegressor

# %%
#RandomForestRegressor
RFR = RandomForestRegressor()
RFR.fit(X_train,Y_train)
pred = RFR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 score for RandomForestReggresor",r2)
# Out:
# Best r2 score for RandomForestReggresor 0.6254904442697158

# %%
#GradientBoostingRegressor

# %%
GBR = GradientBoostingRegressor()
GBR.fit(X_train,Y_train)
pred = GBR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 value for GradientBoostingRegressor",r2)
# Out:
# Best r2 value for GradientBoostingRegressor 0.6202330376806642

# %%
#AdaBoosterRegressor

# %%
ABR = AdaBoostRegressor()
GBR.fit(X_train,Y_train)
pred = GBR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 score for AdaBoosterRegressor",r2)
# Out:
# Best r2 score for AdaBoosterRegressor 0.6189248953986393

# %%
#cross validate our model using Lasoo

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
param_grid = {"alpha" : [0.001,0.01,0.1,1.0,2.0,3.0],
             "random_state" : range(1,10)}

# %%
lassocv = Lasso()
grid_sr = GridSearchCV(lassocv,param_grid=param_grid)
grid_sr.fit(X_train, Y_train)
grid_sr.best_params_
# Out:
# {'alpha': 3.0, 'random_state': 1}

# %%
lass = Lasso(alpha = 3.0, random_state = 1)
lass.fit(X_train, Y_train)
Y_pre = lass.predict(X_test)
r2= r2_score(Y_test,Y_pre)
print(r2)
# Out:
# 0.6039400244688716

# %% [markdown]
# # For best model presiction value we are going to do the Hyperparameter tunning with Linear Regressor

# %%
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False]
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(lm, param_grid, cv=5)
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model for predictions
best_model = grid_search.best_estimator_
Y_pred = best_model.predict(X_test)

# Evaluate the best model using Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)
# Out:
# Best Hyperparameters: {'fit_intercept': True, 'normalize': True}
# Mean Squared Error: 1514165973693287.8

# %%
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False],
#                          'normalize': [True, False]})

# %%
grid_search.best_params_
# Out:
# {'fit_intercept': True, 'normalize': True}

# %%
# Create a Linear Regression model with specified hyperparameters
Final_Project_gross = LinearRegression(fit_intercept=True, normalize=True)

# Fit the model on the training data
Final_Project_gross.fit(X_train, Y_train)

# Make predictions on the testing data
y_pred = Final_Project_gross.predict(X_test)

# Calculate the R-squared score
r2score = r2_score(Y_test, Y_pred)
print(r2score * 100)
# Out:
# 68.21154085975824

# %% [markdown]
# Here is the accuracy of the model with Linear Regression

# %%
#Saving the model

# %%
import joblib
joblib.dump(Final_Project_gross,"Final_project_gross.pkl")
# Out:
# ['Final_project_gross.pkl']

# %% [markdown]
# # Now Prediction for the votes_list column:

# %%
df
# Out:
#       SrNO  movie_names  director_names  duration_list  year_list  \
# 0        1         1114             132             40         73
# 1        2         1265             593             52         58
# 2        3         1376             132             87         53
# 3        4          584             593             48         60
# 4        5         1375             593             77         51
# ...    ...          ...             ...            ...        ...
# 1695  1696         1104             510            111         48
# 1696  1697          551             510              2         47
# 1697  1698         1188             510            115         78
# 1698  1699         1075             510            110         60
# 1699  1700         1668             510              1         55
#
#       rating_list  star_name1  star_name2  star_name3  star_name4  votes_list  \
# 0             9.0         383         561        1105         445   97467.000
# ...

# %%
df.skew()
# Out:
# SrNO              0.000000
# movie_names      -0.000906
# director_names   -0.154501
# duration_list     0.841940
# year_list        -0.314732
# rating_list       0.125155
# star_name1        0.021415
# star_name2        0.004019
# star_name3        0.033987
# star_name4        0.021663
# votes_list        1.171058
# Gross             1.156370
# Genre2            0.173531
# Genre3            0.336308
# dtype: float64

# %% [markdown]
# Observation:
# In the column named duration list votes_list and Gross having the skewed data so we are going to treat the skewness by using the log transforme method

# %%
numerical=df.select_dtypes(include=["int64","int32"]).columns.tolist()
category=df.select_dtypes(include=["object"]).columns.tolist()

# %%
numerical
# Out:
# ['SrNO',
#  'movie_names',
#  'director_names',
#  'duration_list',
#  'year_list',
#  'star_name1',
#  'star_name2',
#  'star_name3',
#  'star_name4',
#  'Genre2',
#  'Genre3']

# %%
#cheking for the outliers
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,15),color = 'green')
plt.tight_layout()

# %%
#percentile method to treat the outliers
from numpy import percentile

columns = df.columns
for j in numerical:
    if isinstance(df[j][0], str) :
        continue
    else:
        #defining quartiles
        quartiles = percentile(df[j], [25,75])
        # calculate min/max
        lower_fence = quartiles[0] - (1.5*(quartiles[1]-quartiles[0]))
        upper_fence = quartiles[1] + (1.5*(quartiles[1]-quartiles[0]))
        df[j] = df[j].apply(lambda x: upper_fence if x > upper_fence else (lower_fence if x < lower_fence else x))

# %%
#cheking for the outliers
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,15),color = 'green')
plt.tight_layout()

# %% [markdown]
# now our dataset is outliers free

# %% [markdown]
# # Spilliting the Dataset into two form Training and testing

# %%
X=df.drop('votes_list',axis=1)
Y=df['votes_list']

# %%
X
# Out:
#       SrNO  movie_names  director_names  duration_list  year_list  \
# 0        1         1114             132       3.713572       73.0
# 1        2         1265             593       3.970292       58.0
# 2        3         1376             132       4.477337       53.0
# 3        4          584             593       3.891820       60.0
# 4        5         1375             593       4.356709       51.0
# ...    ...          ...             ...            ...        ...
# 1695  1696         1104             510       4.718499       48.0
# 1696  1697          551             510       1.098612       47.0
# 1697  1698         1188             510       4.753590       78.0
# 1698  1699         1075             510       4.709530       60.0
# 1699  1700         1668             510       0.693147       55.0
#
#       rating_list  star_name1  star_name2  star_name3  star_name4  \
# 0             9.0         383         561        1105         445
# ...

# %%
Y
# Out:
# 0        97467.000
# 1       471031.375
# 2       471031.375
# 3       471031.375
# 4       471031.375
#            ...
# 1695     30252.000
# 1696    121415.000
# 1697     43730.000
# 1698     90941.000
# 1699     72160.000
# Name: votes_list, Length: 1700, dtype: float64

# %%
X.shape
# Out:
# (1700, 13)

# %%
Y.shape
# Out:
# (1700,)

# %% [markdown]
# Train test split for the dataset:

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=50)

# %%
Y_test=np.array(Y_test,dtype=int)

# %% [markdown]
# # StandardScaler for Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# # Finding best random state for building the Regression Models

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.7608941739558737 on Random State 899

# %% [markdown]
# PCA technique for Dimensionality Reduction

# %%
from sklearn.decomposition import PCA


# Create a PCA instance
pca = PCA(n_components=2)  # Specify the number of components to keep

# Fit the data and perform dimensionality reduction
X_pca = pca.fit_transform(X)

# Print the explained variance ratio
print("Explained Variance Ratio:", pca.explained_variance_ratio_)

# Access the principal components
components = pca.components_
print("Principal Components:")
for i, component in enumerate(components):
    print(f"PC{i+1}: {component}")

# Visualize the transformed data
import matplotlib.pyplot as plt

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=Y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
plt.show()
# Out:
# Explained Variance Ratio: [1.00000000e+00 6.25065633e-11]
# Principal Components:
# PC1: [-1.66090172e-06  2.41955442e-07 -1.53365275e-07 -1.56774625e-10
#  -7.74248017e-09  2.64894339e-09 -6.43305974e-08  6.17269309e-08
#  -1.15882433e-07 -3.20987670e-07  1.00000000e+00 -9.25062385e-10
#   9.17101889e-10]
# PC2: [-4.47147958e-01 -8.93922950e-01 -4.69761797e-03  7.04989850e-05
#  -1.33217942e-03  7.54293874e-04  1.73230551e-02  2.15104096e-02
#   7.64583771e-03  1.07130878e-02 -5.23000821e-07 -4.12531798e-05
#   1.73942605e-04]

# %% [markdown]
# # Regression model with metrics

# %%
  def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=769)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # RMSE - a lower RMSE score is better than a higher one
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score is:", rmse)
    
    # R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of r2 score minus cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
#Linear Regression Model
model=LinearRegression()
reg(model,X,Y)
# Out:
# RMSE Score is: 75267.15717148528
# R2 Score is: 71.23878370708972
# Cross Validation Score: 47.59367231415357
# R2 Score - Cross Validation Score is 23.64511139293615

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-7.49693905e+01, -1.85493163e+00, -6.27472454e+00, -3.33534162e+03,
#         1.36696906e+03,  8.24690980e+03, -1.32064273e+01, -2.19166974e+00,
#        -7.62779162e+00, -1.41692046e+01,  1.62610897e-03,  2.76887193e+02,
#        -1.29372584e+03])

# %%
lm.intercept_
# Out:
# 37833.75678447954

# %%
lm.score(X_train,Y_train)
# Out:
# 0.6882443194920631

# %%
pred=lm.predict(X_test)

# %%
print("predicted result price:",pred)
print("actual price",Y_test)
# Out:
# predicted result price: [ 8.60227177e+04  2.03924453e+05  9.10829189e+04  1.56720558e+05
#   1.48194856e+05  8.93763406e+04  2.40595756e+05  2.62277935e+05
#   3.83251002e+05 -3.16288015e+02  9.16613615e+04  4.26692295e+05
#   3.85149129e+04  1.05655783e+05  1.37890598e+05  1.62016054e+05
#   1.72472874e+05  3.74112573e+05  4.22417481e+05  3.10871423e+05
#   2.79141533e+05  4.34701232e+05  8.97192370e+04  2.11573956e+05
#   9.51259417e+04  7.54946657e+04  6.93179453e+04  7.09484192e+04
#   7.03893086e+04  1.00967888e+05  1.32446848e+05  1.73223064e+05
#   1.22442326e+05  6.25243626e+04 -2.63376407e+02  2.67421427e+05
#   2.48941245e+04  9.74619497e+04  2.88754382e+05  5.62548105e+04
#   1.37648373e+05  1.82110162e+05  1.11449114e+05  1.96964536e+05
#   6.88879081e+04  2.33212666e+05  1.80313290e+04  1.50391127e+05
#   9.74226850e+04  2.73609474e+05  1.28146647e+05  1.03257453e+05
#   2.53331559e+04  2.97967236e+05  4.77407499e+04  2.68290652e+05
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(Y_test,pred))
# Out:
# 0.6823839285599529

# %%
#RandomForestRegressor
RFR = RandomForestRegressor()
RFR.fit(X_train,Y_train)
pred = RFR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 score for RandomForestReggresor",r2)
# Out:
# Best r2 score for RandomForestReggresor 0.7366610630122015

# %%
#GradientBoosterRegression
GBR = GradientBoostingRegressor()
GBR.fit(X_train,Y_train)
pred = GBR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 value for GradientBoostingRegressor",r2)
# Out:
# Best r2 value for GradientBoostingRegressor 0.7456571953134081

# %%
#AdaboosterRegressor
ABR = AdaBoostRegressor()
GBR.fit(X_train,Y_train)
pred = GBR.predict(X_test)
r2 = r2_score(Y_test,pred)
print("Best r2 score for AdaBoosterRegressor",r2)
# Out:
# Best r2 score for AdaBoosterRegressor 0.7451950674320249

# %%
#cross validate our model using Lasoo

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
param_grid = {"alpha" : [0.001,0.01,0.1,1.0,2.0,3.0],
             "random_state" : range(1,100)}

# %%
lassocv = Lasso()
grid_sr = GridSearchCV(lassocv,param_grid=param_grid)
grid_sr.fit(X_train, Y_train)
grid_sr.best_params_
# Out:
# {'alpha': 3.0, 'random_state': 1}

# %%
lass = Lasso(alpha = 3.0, random_state = 1)
lass.fit(X_train, Y_train)
Y_pre = lass.predict(X_test)
r2= r2_score(Y_test,Y_pre)
print(r2)
# Out:
# 0.6823921077843542

# %%
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False]
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(lm, param_grid, cv=5)
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model for predictions
best_model = grid_search.best_estimator_
Y_pred = best_model.predict(X_test)

# Evaluate the best model using Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)
# Out:
# Best Hyperparameters: {'fit_intercept': False, 'normalize': True}
# Mean Squared Error: 5906578284.122721

# %%
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False],
#                          'normalize': [True, False]})

# %%
grid_search.best_params_
# Out:
# {'fit_intercept': False, 'normalize': True}

# %% [markdown]
# HyperParameter tunning with the best model..

# %%
# Create a Linear Regression model with specified hyperparameters
Final_Project_vote = LinearRegression(fit_intercept=True, normalize=True)

# Fit the model on the training data
Final_Project_vote.fit(X_train, Y_train)

# Make predictions on the testing data
y_pred = Final_Project_vote.predict(X_test)

# Calculate the R-squared score
r2score = r2_score(Y_test, Y_pred)
print(r2score * 100)
# Out:
# 68.21154085975824

# %% [markdown]
# # This is the final model prediction accuracy for the votes_list label:

# %%
#saving the final model

# %%
import joblib
joblib.dump(Final_Project_vote,"Final_project_vote.pkl")
# Out:
# ['Final_project_vote.pkl']

# %% [markdown]
# # End of the Project
